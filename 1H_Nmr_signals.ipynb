# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashishmehta786/ML/blob/main/1H_Nmr_signals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Create a list of 20 hydrocarbons with fictional data
hydrocarbons = [
    {
        'Hydrocarbon': 'Methane',
        'Signal': 1,
        'Carbon': 1,
        'Hydrogen': 4,
    },
    {
        'Hydrocarbon': 'Ethane',
        'Signal': 1,
        'Carbon': 2,
        'Hydrogen': 6,
    },
    {
        'Hydrocarbon': 'Propane',
        'Signal': 1,
        'Carbon': 3,
        'Hydrogen': 8,
    },
    {
        'Hydrocarbon': 'Butane',
        'Signal': 1,
        'Carbon': 4,
        'Hydrogen': 10,
    },
    {
        'Hydrocarbon': 'Pentane',
        'Signal': 1,
        'Carbon': 5,
        'Hydrogen': 12,
    },
    {
        'Hydrocarbon': 'Hexane',
        'Signal': 1,
        'Carbon': 6,
        'Hydrogen': 14,
    },
    {
        'Hydrocarbon': 'Heptane',
        'Signal': 1,
        'Carbon': 7,
        'Hydrogen': 16,
    },
    {
        'Hydrocarbon': 'Octane',
        'Signal': 1,
        'Carbon': 8,
        'Hydrogen': 18,
    },
    {
        'Hydrocarbon': 'Nonane',
        'Signal': 1,
        'Carbon': 9,
        'Hydrogen': 20,
    },
    {
        'Hydrocarbon': 'Decane',
        'Signal':1,
        'Carbon': 10,
        'Hydrogen': 22,
    },
    {
        'Hydrocarbon': 'Undecane',
        'Signal': 1,
        'Carbon': 11,
        'Hydrogen': 24,
    },
    {
        'Hydrocarbon': 'Dodecane',
        'Signal': 1,
        'Carbon': 12,
        'Hydrogen': 26,
    },
    {
        'Hydrocarbon': 'Tridecane',
        'Signal': 1,
        'Carbon': 13,
        'Hydrogen': 28,
    },
    {
        'Hydrocarbon': 'Tetradecane',
        'Signal': 1,
        'Carbon': 14,
        'Hydrogen': 30,
    },
    {
        'Hydrocarbon': 'Pentadecane',
        'Signal': 1,
        'Carbon': 15,
        'Hydrogen': 32,
    },
    {
        'Hydrocarbon': 'Hexadecane',
        'Signal': 1,
        'Carbon': 16,
        'Hydrogen': 34,
    },
    {
        'Hydrocarbon': 'Heptadecane',
        'Signal': 1,
        'Carbon': 17,
        'Hydrogen': 36,
    },
    {
        'Hydrocarbon': 'Octadecane',
        'Signal': 1,
        'Carbon': 18,
        'Hydrogen': 38,
    },
    {
        'Hydrocarbon': 'Nonadecane',
        'Signal': 1,
        'Carbon': 19,
        'Hydrogen': 40,
    },
    {
        'Hydrocarbon': 'Eicosane',
        'Signal': 1,
        'Carbon': 20,
        'Hydrogen': 42,
    },
{
        'Hydrocarbon': '1',
        'Signal': 2,
        'Carbon': 2,
        'Hydrogen':5,
    },
{
        'Hydrocarbon': '2',
        'Signal': 2,
        'Carbon': 3,
        'Hydrogen': 8,
    },{
        'Hydrocarbon': '3',
        'Signal': 1,
        'Carbon': 3,
        'Hydrogen': 2,
    },{
        'Hydrocarbon': '4',
        'Signal': 3,
        'Carbon': 3,
        'Hydrogen': 5,
    },{
        'Hydrocarbon': '5',
        'Signal': 1,
        'Carbon': 3,
        'Hydrogen': 6,
    },{
        'Hydrocarbon': '6',
        'Signal': 2,
        'Carbon': 4,
        'Hydrogen': 10,
    },{
        'Hydrocarbon': '7',
        'Signal': 2,
        'Carbon': 4,
        'Hydrogen':8,
    },{
        'Hydrocarbon': '8',
        'Signal': 1,
        'Carbon': 4,
        'Hydrogen': 4,
    },{
        'Hydrocarbon': '9',
        'Signal': 4,
        'Carbon': 4,
        'Hydrogen': 9,
    },{
        'Hydrocarbon': '10',
        'Signal': 2,
        'Carbon': 5,
        'Hydrogen': 14,
    },
]

# Create a DataFrame
df = pd.DataFrame(hydrocarbons)
df.head(1)
# Out:
#   Hydrocarbon  Signal  Carbon  Hydrogen
# 0     Methane       1       1         4

# %%
#df.drop(columns=["Hydrocarbon"],axis=1,inplace=True)
df.head(1)
X=df.iloc[:,1:]
X=X/20
y=df.iloc[:,0]
y=y/20
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15)

# %%
import tensorflow
from tensorflow import keras
from keras.layers import Dense,LeakyReLU
from keras.losses import Huber
from keras import Sequential,Model

# %%
model=Sequential()
model.add(Dense(128,activation="relu",input_dim=2))
model.add(Dense(256, activation="relu"))
model.add(Dense(256, activation="relu"))
model.add(Dense(128, activation="relu"))
model.add(Dense(1 , activation="sigmoid"))
model.compile(optimizer="rmsprop",loss="Huber")
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_60 (Dense)            (None, 128)               384
#
#  dense_61 (Dense)            (None, 256)               33024
#
#  dense_62 (Dense)            (None, 256)               65792
#
#  dense_63 (Dense)            (None, 128)               32896
#
#  dense_64 (Dense)            (None, 1)                 129
#
# ...
# Total params: 132,225
# Trainable params: 132,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(X_train,y_train,epochs=100,validation_data=[X_test,y_test])
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0931 - val_loss: 0.0798
# Epoch 2/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0763 - val_loss: 0.0728
# Epoch 3/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0646 - val_loss: 0.0641
# Epoch 4/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0510 - val_loss: 0.0553
# Epoch 5/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0392 - val_loss: 0.0468
# Epoch 6/100
# 1/1 [==============================] - 0s 48ms/step - loss: 0.0296 - val_loss: 0.0393
# Epoch 7/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0224 - val_loss: 0.0328
# Epoch 8/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0172 - val_loss: 0.0274
# Epoch 9/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0134 - val_loss: 0.0230
# Epoch 10/100
# ...

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import accuracy_score
y_pred=model.predict(X_test)
print(y_pred)
# Out:
# 1/1 [==============================] - 0s 80ms/step
# [[0.05471854]
#  [0.08710105]
#  [0.10846864]
#  [0.10240973]
#  [0.10540123]]

# %%
X_test
# Out:
#     Carbon  Hydrogen
# 29    0.25      0.70
# 2     0.15      0.40
# 27    0.20      0.20
# 1     0.10      0.30
# 23    0.15      0.25
